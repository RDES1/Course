# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Robin Destreel**<br>
# Data Specialist

# %% [markdown]
# *I am interested in data science because it has a lot of possibilities that excites me.* <br> *Besides that, I really want to learn some more skills to develop myself and be more valueable in my work environment*

# %% [markdown]
# ### The code below is supposed to do 1+1 and show the output from it

# %%
1+1
# Out:
# 2

# %% [markdown]
# |Nr.| Value| Quantity|
# |:---|:------|:---------|
# | 1 |This  |   12    |
# | 2 |is    |   3     |
# | 3 |my    |   8     |
# | 4 |table |   45    |
#
#
# <br>
#
#
# - This
# - is
# - the
# - bulletlist
#
# <br>
#
# This is `highlighted` text
